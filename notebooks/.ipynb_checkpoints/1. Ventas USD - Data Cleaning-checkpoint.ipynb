# %% [markdown]
# # Ventas en USD
# ## Limpieza de los datos
#
# Capacitación: Gobernanza de Datos - GCBA

# %% [markdown]
# #### **Librerias y Setup del Notebook**

# %%
# Libs principales
import pandas as pd
import numpy as np

# DataViz libs
import matplotlib.pyplot as plt
import seaborn as sns

# Lib. Utiles
from datetime import datetime

# Setup del Notebooks
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Objetivos del Proyecto
#
#
# **Grupo Perfil Tecnico**
# - En Base al excel “Actividad Ventas en Dolares” identificar posibles análisis a realizar con los datos actuales.
#
# - Con qué problemas de calidad de datos nos encontramos y cómo podríamos resolverlos?
#
# - Calcular la venta en dólares para los distintos productos del total de la base y para los últimos 3 meses del 2020. Deben buscar una base externa para resolver esta cuestión. Adjuntar un excel con sus gráficos, resultados y base incorporada y fuente. Contestar: cómo resolvieron la normalización de los datos?
#
# - Hacer foco en cuestiones de negocios, qué decisiones **podemos** y **no podemos** tomar con la data actual? Qué información agregaría o recomendaría agregar?
#
# - Adjuntar excel con sus gráficos y resultados, y también un word con sus respuestas teóricas.

# %% [markdown]
# ***
#
# ### Agenda - Limpieza de Datos
#
# 1. Encoding/Decoding caracteres especiales en las variables categoricas;
# 2. Verificar, corregir o dropar columnas con muchos datos faltantes;
# 3. Parsear correctamente columna `Date (YYYYMMDD)`;
# 4. Conectar base de `monedas` (cambio/forex), traendo datos del cambio diario, a travez da la fecha presente en `Date (YYYYMMDD)`;
# 5. Analisis de los datos (en otro Notebook).

# %% [markdown]
# ### **Cargando dataset de `ventas` en Jupyter Nb**

# %%
# Caergando archivo en formato Excel y guardandolo en formato csv

# pd.read_excel('../data/ventas_usd.xlsx', engine = 'openpyxl').to_csv('../data/ventas_usd.csv')

# %%
# Cargando dataset en Jupyter, version csv

ventas = pd.read_csv("../data/ventas_usd.csv", index_col = 'Unnamed: 0', encoding = 'utf-8')
ventas.head(3)
# Out:
#    Delivery_Id  amount Pais/Moneda  quantity  units title  \
# 0            1    14.0      México         6      1   NaN
# 1            1    14.0      México         6      1   NaN
# 2            2    94.0   Argentina         2      1   NaN
#
#                        subtitle ean (identificador producto)  \
# 0    Coca-Cola Sabor Original                  7501055300075
# 1    Coca-Cola Sabor Original                  7501055300075
# 2  Marolio Duraznos en Mitades                 7797470001998
#
#                       brand flavor              variant first_driver  \
# 0  Coca-Cola Sabor Original    NaN                  NaN          NaN
# 1  Coca-Cola Sabor Original    NaN                  NaN          NaN
# 2                   Marolio    NaN  Duraznos en Mitades          NaN
#
#   second_driver third_driver package_type  volume_quantity volume_unit  \
# 0           NaN          NaN          NaN            355.0          mL
# 1           NaN          NaN          NaN            355.0          mL
# 2           NaN          NaN                         820.0           g
#
#   nutritional_information category_code category_name category_color  \
# 0                     NaN       BEBIDAS       BEBIDAS         F7E173
# 1                     NaN       BEBIDAS       BEBIDAS         F7E173
# 2                     NaN       ALMACEN      ALMACÃ‰N         FFCB3D
#
#    retail_amount     Date (YYYYMMDD)
# 0           14.0  20200708-171056676
# 1           14.0  20200708-171056676
# 2           94.0  20200708-171056676

# %% [markdown]
# ## Limpieza de los datos

# %% [markdown]
# ### Limpiando problemas con caracteres especiales
#
# El objetivo de esta sección es limpiar los datos de tipo `string` que fueron parseados con caracteres especiales.
#
# Por ejemplo:
#
# `Ala LÃ­quido Lavarropas Baja Espuma` ➞ `Ala Líquido Lavarropas Baja Espuma`

# %%
# Filtrando DF por columnas de tipo "Pandas Object" (string)

ventas_str = ventas[list(ventas.select_dtypes('object').columns)]
# ventas_str.head()

# %%
# ventas_str[ventas_str.apply(lambda x: x.str.contains('Ã'))].head()

# %%
### Conteo de strings unicas que contienen caracteres especiales y dificultan la lectura

# Filtando columnas que contienen caracteres especiales
ventas_str_especiales = ventas_str[ventas_str.apply(lambda x: x.str.contains('Ã'))]

# Proseguiendo con el conteo
ventas_str_especiales_conteo = ventas_str_especiales.nunique().loc[ventas_str_especiales.nunique() > 0]                          
ventas_str_especiales_conteo
# Out:
# subtitle         1995
# brand             154
# flavor             11
# variant          1411
# third_driver        3
# package_type        7
# category_name      28
# dtype: int64

# %%
# Listando nombre de las columnas que contienen caracteres especiales
ventas_str_especiales_cols = ventas_str_especiales_conteo.index.tolist()

# ventas_str_especiales_cols

# %%
# Transformando caracteres especiales, de formato uft-8 a ascii
for col in ventas_str_especiales_cols:
    ventas[col] = ventas[col].str.encode('utf-8').str.decode('ascii', 'ignore')
    
    # Validando la transformación
    ventas_col_carac_esp = ventas[ventas[col].str.contains('Ã', na = False)]
    ventas_col_carac_esp_conteo = ventas_col_carac_esp.nunique().loc[ventas_col_carac_esp.nunique() > 0]
    
    assert len(ventas_col_carac_esp_conteo) == 0
    
# Visualizando el DF modificado
ventas.head(3)
# Out:
#    Delivery_Id  amount Pais/Moneda  quantity  units title  \
# 0            1    14.0      México         6      1   NaN
# 1            1    14.0      México         6      1   NaN
# 2            2    94.0   Argentina         2      1   NaN
#
#                        subtitle ean (identificador producto)  \
# 0    Coca-Cola Sabor Original                  7501055300075
# 1    Coca-Cola Sabor Original                  7501055300075
# 2  Marolio Duraznos en Mitades                 7797470001998
#
#                       brand flavor              variant first_driver  \
# 0  Coca-Cola Sabor Original    NaN                  NaN          NaN
# 1  Coca-Cola Sabor Original    NaN                  NaN          NaN
# 2                   Marolio    NaN  Duraznos en Mitades          NaN
#
#   second_driver third_driver package_type  volume_quantity volume_unit  \
# 0           NaN          NaN          NaN            355.0          mL
# 1           NaN          NaN          NaN            355.0          mL
# 2           NaN          NaN                         820.0           g
#
#   nutritional_information category_code category_name category_color  \
# 0                     NaN       BEBIDAS       BEBIDAS         F7E173
# 1                     NaN       BEBIDAS       BEBIDAS         F7E173
# 2                     NaN       ALMACEN        ALMACN         FFCB3D
#
#    retail_amount     Date (YYYYMMDD)
# 0           14.0  20200708-171056676
# 1           14.0  20200708-171056676
# 2           94.0  20200708-171056676

# %% [markdown]
# ### Datos faltantes

# %%
# Chequeando cantidad de datos faltantes en numero absoluto
# ventas.isna().sum()[ventas.isna().sum() > 0]

# Chequeando cantidad de datos faltantes, en proporcioón
ventas.isna().sum()[ventas.isna().sum() / ventas.shape[0] > .75] / ventas.shape[0]
# Out:
# title                      0.997880
# flavor                     0.959517
# first_driver               0.997880
# second_driver              0.995461
# third_driver               0.997500
# nutritional_information    0.763484
# dtype: float64

# %% [markdown]
# Las columnas con muchos datos faltantes no contribuyen para ese analisis y complican la visualización de la tabla. Vamos droparlas.

# %%
# Listando columnas para dropear
cols_to_drop = ventas.isna().sum()[ventas.isna().sum() / ventas.shape[0] > .8].index.to_list()
cols_to_drop
# Out:
# ['title', 'flavor', 'first_driver', 'second_driver', 'third_driver']

# %%
# Dropando columnas con muchos datos faltantes
ventas.drop(cols_to_drop, axis = 1, inplace = True)

# %%
# Review del dataset
# ventas.head(5)

# %% [markdown]
# ### Organizando la variable `Date`

# %%
# Limpiando string de fecha para obtener apenas el día
fecha = (np.array(ventas['Date (YYYYMMDD)'].str.partition('-'))[:, 0])
# hora = (np.array(ventas['Date (YYYYMMDD)'].str.partition('-'))[:, 2])

ventas['fecha'] = pd.to_datetime(fecha)

# %%
# Establecendo columna con "día de la semana", necesario para matchear monedas y ventas
ventas['weekday'] = ventas['fecha'].dt.strftime('%a')

# %%
# Guargando fecha_min (primer día de la tabla Ventas) y fecha_max (útima día de la tabla Ventas)
fecha_min, fecha_max = ventas['fecha'].min(), ventas['fecha'].max()

fecha_min, fecha_max
# Out:
# (Timestamp('2020-07-01 00:00:00'), Timestamp('2021-04-18 00:00:00'))

# %%
# sorted(cambio_dates['currency'].unique())

# %%
lista_monedas = ventas['Pais/Moneda'].unique().tolist()
siglas = ['MXN', 'ARS', 'PEN', 'COP', 'UYU', 'BRL', 'CLP', 'DOP', 'EUR', 'KES', 'EGP', 'VND', 'MYR', 'USD']

# %%
len(lista_monedas) == len(siglas) # Chequeando si todos las monedas tienen siglas
# Out:
# True

# %%
# Creando diccionario Pais x Sigla
pais_sigla_dict = dict(zip(lista_monedas, siglas))
pais_sigla_dict
# Out:
# {'México': 'MXN',
#  'Argentina': 'ARS',
#  'Perú': 'PEN',
#  'Colombian Peso': 'COP',
#  'Peso Uruguayo': 'UYU',
#  'Real Brasilero': 'BRL',
#  'Peso Chileno': 'CLP',
#  'Dominican Peso': 'DOP',
#  'Euro': 'EUR',
#  'Kenya': 'KES',
#  'Egipto': 'EGP',
#  'Vietnam': 'VND',
#  'Malasia': 'MYR',
#  'Estados Unidos': 'USD'}

# %%
# Creando columna con sigla FOREX
ventas['currency'] = ventas['Pais/Moneda'].map(pais_sigla_dict)

# %%
ventas['date_curr_key'] = ventas['fecha'].dt.strftime('%Y-%m-%d') + ventas['currency']

# %%
ventas.head(3)
# Out:
#    Delivery_Id  amount Pais/Moneda  quantity  units  \
# 0            1    14.0      México         6      1
# 1            1    14.0      México         6      1
# 2            2    94.0   Argentina         2      1
#
#                        subtitle ean (identificador producto)  \
# 0    Coca-Cola Sabor Original                  7501055300075
# 1    Coca-Cola Sabor Original                  7501055300075
# 2  Marolio Duraznos en Mitades                 7797470001998
#
#                       brand              variant package_type  \
# 0  Coca-Cola Sabor Original                  NaN          NaN
# 1  Coca-Cola Sabor Original                  NaN          NaN
# 2                   Marolio  Duraznos en Mitades
#
#    volume_quantity volume_unit nutritional_information category_code  \
# 0            355.0          mL                     NaN       BEBIDAS
# 1            355.0          mL                     NaN       BEBIDAS
# 2            820.0           g                     NaN       ALMACEN
#
#   category_name category_color  retail_amount     Date (YYYYMMDD)      fecha  \
# 0       BEBIDAS         F7E173           14.0  20200708-171056676 2020-07-08
# 1       BEBIDAS         F7E173           14.0  20200708-171056676 2020-07-08
# 2        ALMACN         FFCB3D           94.0  20200708-171056676 2020-07-08
#
#   weekday currency  date_curr_key
# 0     Wed      MXN  2020-07-08MXN
# 1     Wed      MXN  2020-07-08MXN
# 2     Wed      ARS  2020-07-08ARS

# %%
# ventas['date_curr_key_wkd'] = ventas['fecha'].dt.strftime('%Y-%m-%d') + ventas['currency']

# %%
ventas.loc[:, 'fecha_wkend'] = ventas['fecha']

# %%
ventas.loc[ventas['weekday'] == 'Sat', 'fecha_wkend'] = ventas[ventas['weekday'] == 'Sat']['fecha'] - np.timedelta64(1, 'D')

# %%
ventas.loc[ventas['weekday'] == 'Sun', 'fecha_wkend'] = ventas[ventas['weekday'] == 'Sun']['fecha'] - np.timedelta64(2, 'D')

# %%
ventas['date_curr_key_wkd'] = ventas['fecha_wkend'].dt.strftime('%Y-%m-%d') + ventas['currency']

# %%
ventas[ventas['weekday'] == 'Sun'].head(3)
# Out:
#       Delivery_Id  amount Pais/Moneda  quantity  units  \
# 8192          780    40.0      México         3      1
# 8193          780    13.0      México         1      1
# 8194          780    40.0      México         3      1
#
#                                            subtitle  \
# 8192  Combo 4x Coca-Cola Sabor Original Ret 500 mL
# 8193                  Kinder Chocolate Maxi Barra
# 8194  Combo 4x Coca-Cola Sabor Original Ret 500 mL
#
#      ean (identificador producto)   brand  \
# 8192                   combomex14   Combo
# 8193                     80050094  Kinder
# 8194                   combomex14   Combo
#
#                                      variant package_type  volume_quantity  \
# 8192  4x Coca-Cola Sabor Original Ret 500 mL                           1.0
# 8193                   Chocolate Maxi Barra                           21.0
# 8194  4x Coca-Cola Sabor Original Ret 500 mL                           1.0
#
#      volume_unit nutritional_information category_code category_name  \
# 8192       Combo                     NaN     COMBOSMEX        COMBOS
# 8193           g                     NaN     DULCES_MX        DULCES
# 8194       Combo                     NaN     COMBOSMEX        COMBOS
#
#      category_color  retail_amount     Date (YYYYMMDD)      fecha weekday  \
# 8192         2DCC76           40.0  20201011-011319087 2020-10-11     Sun
# 8193        #F6D05C           13.0  20201011-011319087 2020-10-11     Sun
# 8194         2DCC76           40.0  20201011-011319087 2020-10-11     Sun
#
#      currency  date_curr_key fecha_wkend date_curr_key_wkd
# 8192      MXN  2020-10-11MXN  2020-10-09     2020-10-09MXN
# 8193      MXN  2020-10-11MXN  2020-10-09     2020-10-09MXN
# 8194      MXN  2020-10-11MXN  2020-10-09     2020-10-09MXN

# %% [markdown]
# ### Descargando tabla soporte: Monedas
#
# La tabla soporte trae los datos historicos diarios de la cotización del dolar para diferentes monedas.
#
# De ese dataset necesitamos dos cosas:
# 1. Filtrar apenas los datos que involucren USD;
# 2. Filtrar los datos que se encuentren dentro del timespan del dataset de `Ventas`.

# %% [markdown]
# #### Cargando la table `monedas` al Jupyter Notebook

# %%
# Cargando datos historicos de las monedas al Jupyter Notebook
monedas = pd.read_csv('../data/forex.csv')

# %% [markdown]
# #### Filtrando los datos de `monedas` para mostrar apenas registros que involucren USD.

# %%
# Filtrando tabla monedas para incluir apenas las que involucran dolar y moneda de interés de la tabla Ventas
monedas = monedas[monedas['slug'].str.startswith('USD')]
monedas.head()
# Out:
#           slug        date    open    high     low   close currency
# 46363  USD/ZMW  2013-01-03  5.1762  5.1762  5.1762  5.1893      ZMW
# 46364  USD/ZMW  2013-01-04  5.1667  5.1667  5.1667  5.2021      ZMW
# 46365  USD/ZMW  2013-01-07  5.2223  5.2230  5.2223  5.1420      ZMW
# 46366  USD/ZMW  2013-01-08  5.1481  5.1531  5.1481  5.1892      ZMW
# 46367  USD/ZMW  2013-01-09  5.1594  5.1594  5.1594  5.1651      ZMW

# %% [markdown]
# #### Cumpliendo con el timespan de `Ventas`

# %%
# Parseando la variable "date" en formato Pandas Datetime
monedas_datetime = pd.to_datetime(monedas['date'])

# %%
# Filtrando tabla de monedas para incluir apenas el espacio temporal de la tabla de Ventas
monedas_date = monedas_datetime[(monedas_datetime <= fecha_max) & (monedas_datetime >= fecha_min)]
monedas_date.head()
# Out:
# 48293   2020-07-01
# 48294   2020-07-02
# 48295   2020-07-03
# 48296   2020-07-06
# 48297   2020-07-07
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# #### Check de integridad de las fechas máx y min de los dos datasets

# %%
# Chequendo timespan de los dos datasets
# print(monedas_date.min() == fecha_min) # True
# print(monedas_date.max() == fecha_max) # False

# Chequeando si los valores maximos de las fechas en los dos datasets son dia de semana y fin de semana
print('Monedas fecha máxima: ', monedas_date.max(), monedas_date.max().strftime('%a'), '\n', 
      'Ventas fecha máxima: ', fecha_max, fecha_max.strftime('%a'))

# Subtrayedno dos días de la fecha Máxima de ventas y chequeando si es igual a la fecha máx de Monedas
monedas_date.max() == (fecha_max - np.timedelta64(2, 'D'))
# Out:
# Monedas fecha máxima:  2021-04-16 00:00:00 Fri
#  Ventas fecha máxima:  2021-04-18 00:00:00 Sun
# True

# %% [markdown]
# Las datas máximas en los dos datasets son distintas porque las ventas siguen pasando en los fines de semana, pero las cotizaciones de monedas solo durante los días laborales.
#
# Por eso, entiendese que los dos datasets están en el mismo _timespan_. **Estamos ok con ese check!**

# %%
monedas['date_curr_key_wkd'] = monedas['date'] + monedas['currency']

# %%
monedas
# Out:
#             slug        date       open       high        low      close  \
# 46363    USD/ZMW  2013-01-03   5.176200   5.176200   5.176200   5.189300
# 46364    USD/ZMW  2013-01-04   5.166700   5.166700   5.166700   5.202100
# 46365    USD/ZMW  2013-01-07   5.222300   5.223000   5.222300   5.142000
# 46366    USD/ZMW  2013-01-08   5.148100   5.153100   5.148100   5.189200
# 46367    USD/ZMW  2013-01-09   5.159400   5.159400   5.159400   5.165100
# ...          ...         ...        ...        ...        ...        ...
# 1434536  USD/MXN  2021-06-07  19.958401  19.962151  19.725201  19.943899
# 1434537  USD/MXN  2021-06-08  19.824200  19.852390  19.738400  19.822399
# 1434538  USD/MXN  2021-06-09  19.701981  19.706800  19.587700  19.702080
# 1434539  USD/MXN  2021-06-10  19.736601  19.769650  19.647900  19.730280
# 1434540  USD/MXN  2021-06-11  19.702700  19.961611  19.624741  19.703199
#
#         currency date_curr_key_wkd
# 46363        ZMW     2013-01-03ZMW
# 46364        ZMW     2013-01-04ZMW
# 46365        ZMW     2013-01-07ZMW
# 46366        ZMW     2013-01-08ZMW
# 46367        ZMW     2013-01-09ZMW
# ...          ...               ...
# 1434536      MXN     2021-06-07MXN
# 1434537      MXN     2021-06-08MXN
# 1434538      MXN     2021-06-09MXN
# 1434539      MXN     2021-06-10MXN
# 1434540      MXN     2021-06-11MXN
#
# [359772 rows x 8 columns]

# %%
ventas_merged = ventas.merge(monedas[['slug', 'close', 'date_curr_key_wkd']], how = 'left',  on = 'date_curr_key_wkd')
ventas_merged
# Out:
#         Delivery_Id  amount     Pais/Moneda  quantity  units  \
# 0                 1    14.0          México         6      1
# 1                 1    14.0          México         6      1
# 2                 2    94.0       Argentina         2      1
# 3                 2   205.0       Argentina         1      1
# 4                 2    97.0       Argentina         1      1
# ...             ...     ...             ...       ...    ...
# 324053        33045   600.0  Colombian Peso         2      1
# 324054        33046    12.0          México         1      1
# 324055        33046    12.0          México         1      1
# 324056        33046    37.0          México         1      1
# 324057        33046    19.0          México         1      1
#
#                                      subtitle ean (identificador producto)  \
# 0                  Coca-Cola Sabor Original                  7501055300075
# 1                  Coca-Cola Sabor Original                  7501055300075
# 2                Marolio Duraznos en Mitades                 7797470001998
# 3          Ala Lquido Lavarropas Baja Espuma                 7791290787230
# 4        Higienol Papel Higinico Simple Hoja                 7790250014904
# ...                                       ...                          ...
# 324053       Nucita Leche Chocolate y Nueces                 7702011012401
# 324054                 Boing Jugo de Manzana                   19836103052
# 324055                   Boing Jugo de Fresa                      75003166
# 324056  Chip's Papas Fritas Sabor Sal de Mar                 7501000266203
# 324057                    A Granel Salchicha                       GEN02MX
#
#                            brand                        variant package_type  \
# 0       Coca-Cola Sabor Original                            NaN          NaN
# 1       Coca-Cola Sabor Original                            NaN          NaN
# 2                        Marolio            Duraznos en Mitades
# 3                            Ala  Lquido Lavarropas Baja Espuma
# 4                       Higienol     Papel Higinico Simple Hoja
# ...                          ...                            ...          ...
# 324053                    Nucita       Leche Chocolate y Nueces          NaN
# 324054                     Boing                Jugo de Manzana          NaN
# 324055                     Boing                  Jugo de Fresa          NaN
# 324056                    Chip's  Papas Fritas Sabor Sal de Mar          NaN
# 324057                  A Granel                      Salchicha          NaN
#
#         volume_quantity volume_unit nutritional_information  \
# 0                 355.0          mL                     NaN
# 1                 355.0          mL                     NaN
# 2                 820.0           g                     NaN
# 3                   1.4           L                     NaN
# 4                   4.0           U                     NaN
# ...                 ...         ...                     ...
# 324053             14.0           g                     NaN
# 324054            500.0          mL                     NaN
# 324055            500.0          mL                     NaN
# 324056            170.0           g                     NaN
# 324057            250.0           g                     NaN
#
#              category_code      category_name category_color  retail_amount  \
# 0                  BEBIDAS            BEBIDAS         F7E173           14.0
# 1                  BEBIDAS            BEBIDAS         F7E173           14.0
# 2                  ALMACEN             ALMACN         FFCB3D           94.0
# 3                 LIMPIEZA           LIMPIEZA         71DBCA          205.0
# 4         CUIDADO_PERSONAL   CUIDADO PERSONAL         FF9898           97.0
# ...                    ...                ...            ...            ...
# 324053  GALLETAS_DULCES_CO  GALLETAS & DULCES         FFC26A          600.0
# 324054    BEBIDASYJUGOS_MX    BEBIDAS Y JUGOS        #C3E275           12.0
# 324055    BEBIDASYJUGOS_MX    BEBIDAS Y JUGOS        #C3E275           12.0
# 324056           SNACKSMEX             SNACKS         FFA368           37.0
# 324057        ABARROTESMEX          ABARROTES         FFCB3D           19.0
#
#            Date (YYYYMMDD)      fecha weekday currency  date_curr_key  \
# 0       20200708-171056676 2020-07-08     Wed      MXN  2020-07-08MXN
# 1       20200708-171056676 2020-07-08     Wed      MXN  2020-07-08MXN
# 2       20200708-171056676 2020-07-08     Wed      ARS  2020-07-08ARS
# 3       20200708-171056676 2020-07-08     Wed      ARS  2020-07-08ARS
# 4       20200708-171056676 2020-07-08     Wed      ARS  2020-07-08ARS
# ...                    ...        ...     ...      ...            ...
# 324053  20201213-220312717 2020-12-13     Sun      COP  2020-12-13COP
# 324054  20201213-220312717 2020-12-13     Sun      MXN  2020-12-13MXN
# 324055  20201213-220312717 2020-12-13     Sun      MXN  2020-12-13MXN
# 324056  20201213-220312717 2020-12-13     Sun      MXN  2020-12-13MXN
# 324057  20201213-220312717 2020-12-13     Sun      MXN  2020-12-13MXN
#
#        fecha_wkend date_curr_key_wkd     slug        close
# 0       2020-07-08     2020-07-08MXN  USD/MXN    22.792700
# 1       2020-07-08     2020-07-08MXN  USD/MXN    22.792700
# 2       2020-07-08     2020-07-08ARS  USD/ARS    70.871902
# 3       2020-07-08     2020-07-08ARS  USD/ARS    70.871902
# 4       2020-07-08     2020-07-08ARS  USD/ARS    70.871902
# ...            ...               ...      ...          ...
# 324053  2020-12-11     2020-12-11COP  USD/COP  3418.699951
# 324054  2020-12-11     2020-12-11MXN  USD/MXN    19.990700
# 324055  2020-12-11     2020-12-11MXN  USD/MXN    19.990700
# 324056  2020-12-11     2020-12-11MXN  USD/MXN    19.990700
# 324057  2020-12-11     2020-12-11MXN  USD/MXN    19.990700
#
# [324058 rows x 26 columns]

# %%
# Corregindo valores faltantes de Estados Unidos, una vez que no hay cotación USD/USD
ventas_merged.loc[ventas_merged['currency'] == 'USD', 'close'] = ventas_merged['retail_amount']

# %%
# Corregindo valores faltantes de Kenya por la cotacion del dolar de hoy (2021-07-21)
ventas_merged[ventas_merged['currency'] == 'KES']['close'] = 108.04

# %%
ventas_merged['usd_retail_amount'] = ventas_merged['retail_amount'] / ventas_merged['close']

# %%
# ventas_merged[ventas_merged['subtitle'] == 'Ego Cera para Cabello Matte Men ']
ventas_merged[100:200]
# Out:
#      Delivery_Id  amount Pais/Moneda  quantity  units  \
# 100           10     0.1        Perú         5      1
# 101           10     4.0        Perú         1      1
# 102           10     0.5        Perú         2      1
# 103           10     1.0        Perú         3      1
# 104           10     1.0        Perú         1      1
# ..           ...     ...         ...       ...    ...
# 195           16    65.0   Argentina         2      1
# 196           16    65.0   Argentina         2      1
# 197           16    60.0   Argentina         2      1
# 198           16   192.0   Argentina         1      1
# 199           16    65.0   Argentina         2      1
#
#                                              subtitle  \
# 100                        Arcor Caramelo Sabor Limn
# 101                                M&M's  Chocolates
# 102             Topline Chicles Sabor Inca Kola Zero
# 103                     Mogul Gomitas Rollo Frutal
# 104  Arcor Tableta de Chocolate Semiamargo 50% Cacao
# ..                                                ...
# 195                        Coca-Cola Sabor Original
# 196                             Coca-Cola Sin Azcar
# 197                        Milka Oreo Alfajor Triple
# 198                        Aguila Chocolate de Taza
# 199                        Coca-Cola Sabor Original
#
#     ean (identificador producto)                     brand  \
# 100                7757174384926                     Arcor
# 101                  40000514480                    M&M's
# 102                7757174008228                   Topline
# 103                7790580603809                     Mogul
# 104                7790580120399                     Arcor
# ..                           ...                       ...
# 195                7790895000782  Coca-Cola Sabor Original
# 196                7790895067532       Coca-Cola Sin Azcar
# 197                7622300835620                     Milka
# 198                7790407031013                    Aguila
# 199                7790895000782  Coca-Cola Sabor Original
#
#                                        variant package_type  volume_quantity  \
# 100                        Caramelo Sabor Limn                           1.0
# 101                                 Chocolates                          48.0
# 102               Chicles Sabor Inca Kola Zero                           7.0
# 103                     Gomitas Rollo Frutal                            35.0
# 104  Tableta de Chocolate Semiamargo 50% Cacao                          25.0
# ..                                         ...          ...              ...
# 195                                        NaN          NaN            500.0
# 196                                        NaN          NaN            500.0
# 197                        Oreo Alfajor Triple                          55.0
# 198                          Chocolate de Taza                         100.0
# 199                                        NaN          NaN            500.0
#
#     volume_unit                          nutritional_information  \
# 100           g                                              NaN
# 101           g                                              NaN
# 102           g                                              NaN
# 103           g                                              NaN
# 104           g                                              NaN
# ..          ...                                              ...
# 195          mL  http://www.cocacolalatinamerica.com/es/ar/home/
# 196          mL  http://www.cocacolalatinamerica.com/es/ar/home/
# 197           g                                              NaN
# 198           g
# 199          mL  http://www.cocacolalatinamerica.com/es/ar/home/
#
#                  category_code           category_name category_color  \
# 100                  KIOSKO_PE                  KIOSCO         FFA368
# 101                  KIOSKO_PE                  KIOSCO         FFA368
# 102                  KIOSKO_PE                  KIOSCO         FFA368
# 103                  KIOSKO_PE                  KIOSCO         FFA368
# 104                  KIOSKO_PE                  KIOSCO         FFA368
# ..                         ...                     ...            ...
# 195                    BEBIDAS                 BEBIDAS         F7E173
# 196                    BEBIDAS                 BEBIDAS         F7E173
# 197  ALFAJORES_Y_CHOCOLATES_AR  ALFAJORES Y CHOCOLATES         74B3FF
# 198  ALFAJORES_Y_CHOCOLATES_AR  ALFAJORES Y CHOCOLATES         74B3FF
# 199                    BEBIDAS                 BEBIDAS         F7E173
#
#      retail_amount     Date (YYYYMMDD)      fecha weekday currency  \
# 100            0.1  20200708-171056676 2020-07-08     Wed      PEN
# 101            4.0  20200708-171056676 2020-07-08     Wed      PEN
# 102            0.5  20200708-171056676 2020-07-08     Wed      PEN
# 103            1.0  20200708-171056676 2020-07-08     Wed      PEN
# 104            1.0  20200708-171056676 2020-07-08     Wed      PEN
# ..             ...                 ...        ...     ...      ...
# 195           65.0  20200708-171056676 2020-07-08     Wed      ARS
# 196           65.0  20200708-171056676 2020-07-08     Wed      ARS
# 658                                          Cerveja         Lata
# 659   Coca-Cola Sabor Original Lata 350Ml. + Coxinha
# 780                                              NaN          NaN
# 781                                              NaN          NaN
# 995                                              NaN          NaN
# 996                                              NaN          NaN
# 1046                               Margarina Com Sal         Pote
# 1047                               Margarina Com Sal         Pote
#
#       volume_quantity volume_unit               nutritional_information  \
# 239               3.0           L           https://www.cocacola.com.br
# 240             400.0           g                                   NaN
# 341               1.0       Combo    https://www.cocacolabrasil.com.br/
# 342               1.0       Combo    https://www.cocacolabrasil.com.br/
# 343               1.6          Kg                                   NaN
# 344               1.0       Combo    https://www.cocacolabrasil.com.br/
# 345               1.0       Combo    https://www.cocacolabrasil.com.br/
# 346               1.6          Kg                                   NaN
# 461               1.0       Combo    https://www.cocacolabrasil.com.br/
# 462               1.0       Combo    https://www.cocacolabrasil.com.br/
# 463               1.6          Kg                                   NaN
# 464               1.0       Combo    https://www.cocacolabrasil.com.br/
# 465               1.0       Combo    https://www.cocacolabrasil.com.br/
# 466               1.6          Kg                                   NaN
# 571             330.0          mL                 https://kaiser.com.br
# 572             600.0          mL                 https://kaiser.com.br
# 573             350.0          mL                 https://kaiser.com.br
# 574             500.0           g           https://www.melitta.com.br/
# 575             500.0          mL                                   NaN
# 576               1.0          Kg                                   NaN
# 577              85.0           g            https://www.nissin.com.br/
# 578               3.0           U                                   NaN
# 579             126.0           g  https://br.mondelezinternational.com
# 580             330.0          mL                 https://kaiser.com.br
# 581             600.0          mL                 https://kaiser.com.br
# 582             350.0          mL                 https://kaiser.com.br
# 583             500.0           g           https://www.melitta.com.br/
# 584             500.0          mL                                   NaN
# 585               1.0          Kg                                   NaN
# 586              85.0           g            https://www.nissin.com.br/
# 587               3.0           U                                   NaN
# 588             126.0           g  https://br.mondelezinternational.com
# 589             330.0          mL                 https://kaiser.com.br
# 622             473.0          mL                                   NaN
# 623             473.0          mL                                   NaN
# 624               1.0       Combo    https://www.cocacolabrasil.com.br/
# 637             330.0          mL                 https://kaiser.com.br
# 638             330.0          mL                 https://kaiser.com.br
# 654             473.0          mL                                   NaN
# 655             473.0          mL                                   NaN
# 656               1.0       Combo    https://www.cocacolabrasil.com.br/
# 657             473.0          mL                                   NaN
# 658             473.0          mL                                   NaN
# 659               1.0       Combo    https://www.cocacolabrasil.com.br/
# 780               2.0           L           https://www.cocacola.com.br
# 781               2.0           L           https://www.cocacola.com.br
# 995               2.0           L           https://www.cocacola.com.br
# 996               2.0           L           https://www.cocacola.com.br
# 1046            500.0           g                  http://qualy.com.br/
# 1047            500.0           g                  http://qualy.com.br/
#
#               category_code      category_name category_color  retail_amount  \
# 239               BEBIDASBR            BEBIDAS         F7E173           11.9
# 240           CAFE_DA_MANHA        CAF DA MANH         FFA4A4            6.3
# 341                COMBOSBR             COMBOS         2DCC76           10.0
# 342                COMBOSBR             COMBOS         2DCC76            8.7
# 343                 LIMPEZA            LIMPEZA         71DBCA           18.0
# 344                COMBOSBR             COMBOS         2DCC76           10.0
# 345                COMBOSBR             COMBOS         2DCC76            8.7
# 346                 LIMPEZA            LIMPEZA         71DBCA           18.0
# 461                COMBOSBR             COMBOS         2DCC76           10.0
# 462                COMBOSBR             COMBOS         2DCC76            8.7
# 463                 LIMPEZA            LIMPEZA         71DBCA           18.0
# 464                COMBOSBR             COMBOS         2DCC76           10.0
# 465                COMBOSBR             COMBOS         2DCC76            8.7
# 466                 LIMPEZA            LIMPEZA         71DBCA           18.0
# 571      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 572      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            9.5
# 573      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.5
# 574           CAFE_DA_MANHA        CAF DA MANH         FFA4A4           12.6
# 575                 LIMPEZA            LIMPEZA         71DBCA            2.2
# 576                 LIMPEZA            LIMPEZA         71DBCA            8.7
# 577               MERCADOBR          MERCEARIA         FFCB3D            2.1
# 578                 LIMPEZA            LIMPEZA         71DBCA            4.5
# 579   SALGADOS_E_LANCHINHOS     SNACKS & DOCES         FFA368            5.5
# 580      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 581      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            9.5
# 582      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.5
# 583           CAFE_DA_MANHA        CAF DA MANH         FFA4A4           12.6
# 584                 LIMPEZA            LIMPEZA         71DBCA            2.2
# 585                 LIMPEZA            LIMPEZA         71DBCA            8.7
# 586               MERCADOBR          MERCEARIA         FFCB3D            2.1
# 587                 LIMPEZA            LIMPEZA         71DBCA            4.5
# 588   SALGADOS_E_LANCHINHOS     SNACKS & DOCES         FFA368            5.5
# 589      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 622      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.2
# 623      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 624                COMBOSBR             COMBOS         2DCC76           10.0
# 637      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 638      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 654      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.2
# 655      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 656                COMBOSBR             COMBOS         2DCC76           10.0
# 657      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.2
# 658      ALCOOL_E_TABACARIA  BEBIDAS LCOOLICAS         FFCB78            5.6
# 659                COMBOSBR             COMBOS         2DCC76           10.0
# 780               BEBIDASBR            BEBIDAS         F7E173           10.0
# 781               BEBIDASBR            BEBIDAS         F7E173           10.0
# 995               BEBIDASBR            BEBIDAS         F7E173           10.0
# 996               BEBIDASBR            BEBIDAS         F7E173           10.0
# 1046              LACTEOSBR          LATICNIOS         80C8EA            7.6
# 1047              LACTEOSBR          LATICNIOS         80C8EA            7.6
#
#          Date (YYYYMMDD)      fecha weekday currency  date_curr_key  \
# 622   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           0.966938
# 623   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.041318
# 624   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.859496
# 637   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.041318
# 638   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.041318
# 654   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           0.966938
# 655   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.041318
# 656   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.859496
# 657   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           0.966938
# 658   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.041318
# 659   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.859496
# 780   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.859496
# 781   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.859496
# 995   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.859496
# 996   2020-07-08     2020-07-08BRL  USD/BRL  5.3778           1.859496
# 1046  2020-10-09     2020-10-09BRL  USD/BRL  5.5986           1.357482
# 1047  2020-10-09     2020-10-09BRL  USD/BRL  5.5986           1.357482

# %%
ventas_merged['revenue'] = ventas_merged['usd_retail_amount'] * ventas_merged['quantity']

# %%
ventas_merged.head()
# Out:
#    Delivery_Id  amount Pais/Moneda  quantity  units  \
# 0            1    14.0      México         6      1
# 1            1    14.0      México         6      1
# 2            2    94.0   Argentina         2      1
# 3            2   205.0   Argentina         1      1
# 4            2    97.0   Argentina         1      1
#
#                                subtitle ean (identificador producto)  \
# 0            Coca-Cola Sabor Original                  7501055300075
# 1            Coca-Cola Sabor Original                  7501055300075
# 2          Marolio Duraznos en Mitades                 7797470001998
# 3    Ala Lquido Lavarropas Baja Espuma                 7791290787230
# 4  Higienol Papel Higinico Simple Hoja                 7790250014904
#
#                       brand                        variant package_type  \
# 0  Coca-Cola Sabor Original                            NaN          NaN
# 1  Coca-Cola Sabor Original                            NaN          NaN
# 2                   Marolio            Duraznos en Mitades
# 3                       Ala  Lquido Lavarropas Baja Espuma
# 4                  Higienol     Papel Higinico Simple Hoja
#
#    volume_quantity volume_unit nutritional_information     category_code  \
# 0            355.0          mL                     NaN           BEBIDAS
# 1            355.0          mL                     NaN           BEBIDAS
# 2            820.0           g                     NaN           ALMACEN
# 3              1.4           L                     NaN          LIMPIEZA
# 4              4.0           U                     NaN  CUIDADO_PERSONAL
#
#       category_name category_color  retail_amount     Date (YYYYMMDD)  \
# 0           BEBIDAS         F7E173           14.0  20200708-171056676
# 1           BEBIDAS         F7E173           14.0  20200708-171056676
# 2            ALMACN         FFCB3D           94.0  20200708-171056676
# 3          LIMPIEZA         71DBCA          205.0  20200708-171056676
# 4  CUIDADO PERSONAL         FF9898           97.0  20200708-171056676
#
#        fecha weekday currency  date_curr_key fecha_wkend date_curr_key_wkd  \
# 0 2020-07-08     Wed      MXN  2020-07-08MXN  2020-07-08     2020-07-08MXN
# 1 2020-07-08     Wed      MXN  2020-07-08MXN  2020-07-08     2020-07-08MXN
# 2 2020-07-08     Wed      ARS  2020-07-08ARS  2020-07-08     2020-07-08ARS
# 3 2020-07-08     Wed      ARS  2020-07-08ARS  2020-07-08     2020-07-08ARS
# 4 2020-07-08     Wed      ARS  2020-07-08ARS  2020-07-08     2020-07-08ARS
#
#       slug      close  usd_retail_amount   revenue
# 0  USD/MXN  22.792700           0.614232  3.685390
# 1  USD/MXN  22.792700           0.614232  3.685390
# 2  USD/ARS  70.871902           1.326337  2.652673
# 3  USD/ARS  70.871902           2.892543  2.892543
# 4  USD/ARS  70.871902           1.368667  1.368667

# %%
ventas_merged[ventas_merged['usd_retail_amount'] > 100]
# Out:
#         Delivery_Id   amount Pais/Moneda  quantity  units  \
# 167180        16988  43956.0      México         1      1
# 167271        16988  43956.0      México         1      1
# 167273        16988  43956.0      México         1      1
# 167316        16988  43956.0      México         1      1
# 167318        16988  43956.0      México         1      1
#
#                                      subtitle ean (identificador producto)  \
# 167180  Cloralex Desinfectante Antibacterial                      75000592
# 167271  Cloralex Desinfectante Antibacterial                      75000592
# 167273  Cloralex Desinfectante Antibacterial                      75000592
# 167316  Cloralex Desinfectante Antibacterial                      75000592
# 167318  Cloralex Desinfectante Antibacterial                      75000592
#
#            brand                      variant package_type  volume_quantity  \
# 167180  Cloralex  Desinfectante Antibacterial          NaN            250.0
# 167271  Cloralex  Desinfectante Antibacterial          NaN            250.0
# 167273  Cloralex  Desinfectante Antibacterial          NaN            250.0
# 167316  Cloralex  Desinfectante Antibacterial          NaN            250.0
# 167318  Cloralex  Desinfectante Antibacterial          NaN            250.0
#
#        volume_unit nutritional_information category_code category_name  \
# 167180          mL                     NaN   LIMPIEZAMEX      LIMPIEZA
# 167271          mL                     NaN   LIMPIEZAMEX      LIMPIEZA
# 167273          mL                     NaN   LIMPIEZAMEX      LIMPIEZA
# 167316          mL                     NaN   LIMPIEZAMEX      LIMPIEZA
# 167318          mL                     NaN   LIMPIEZAMEX      LIMPIEZA
#
#        category_color  retail_amount     Date (YYYYMMDD)      fecha weekday  \
# 167180         71DBCA        43956.0  20201130-180426175 2020-11-30     Mon
# 167271         71DBCA        43956.0  20201130-180426175 2020-11-30     Mon
# 167273         71DBCA        43956.0  20201130-180426175 2020-11-30     Mon
# 167316         71DBCA        43956.0  20201130-180426175 2020-11-30     Mon
# 167318         71DBCA        43956.0  20201130-180426175 2020-11-30     Mon
#
#        currency  date_curr_key fecha_wkend date_curr_key_wkd     slug  \
# 167180      MXN  2020-11-30MXN  2020-11-30     2020-11-30MXN  USD/MXN
# 167271      MXN  2020-11-30MXN  2020-11-30     2020-11-30MXN  USD/MXN
# 167273      MXN  2020-11-30MXN  2020-11-30     2020-11-30MXN  USD/MXN
# 167316      MXN  2020-11-30MXN  2020-11-30     2020-11-30MXN  USD/MXN
# 167318      MXN  2020-11-30MXN  2020-11-30     2020-11-30MXN  USD/MXN
#
#             close  usd_retail_amount      revenue
# 167180  20.038071        2193.624326  2193.624326
# 167271  20.038071        2193.624326  2193.624326
# 167273  20.038071        2193.624326  2193.624326
# 167316  20.038071        2193.624326  2193.624326
# 167318  20.038071        2193.624326  2193.624326

# %%
# Conforme datos del sitio de Walmart Mexico
ventas_merged.loc[ventas_merged['ean (identificador producto)'] == '75000592', 'usd_retail_amount'] = 2.4463

# %%
# Recalculando con valores correctos
ventas_merged['revenue'] = ventas_merged['usd_retail_amount'] * ventas_merged['quantity']

# %%
to_keep = [
 'Delivery_Id',
 'amount',
#  'Pais/Moneda',
 'quantity',
 'units',
 'subtitle',
 'ean (identificador producto)',
 'brand',
#  'variant',
#  'package_type',
#  'volume_quantity',
#  'volume_unit',
#  'nutritional_information',
#  'category_code',
#  'category_name',
#  'category_color',
 'retail_amount',
#  'Date (YYYYMMDD)',
 'fecha',
 'weekday',
 'currency',
#  'date_curr_key',
#  'fecha_wkend',
#  'date_curr_key_wkd',
#  'slug',
#  'close',
 'usd_retail_amount',
 'revenue'
]

# %%
# ventas_merged[to_keep].to_csv('../data/ventas_cleaned.csv', header = True, index = False)

# %%
pd.read_csv('../data/ventas_cleaned.csv')
# Out:
#         Delivery_Id  amount  quantity  units  \
# 0                 1    14.0         6      1
# 1                 1    14.0         6      1
# 2                 2    94.0         2      1
# 3                 2   205.0         1      1
# 4                 2    97.0         1      1
# ...             ...     ...       ...    ...
# 324053        33045   600.0         2      1
# 324054        33046    12.0         1      1
# 324055        33046    12.0         1      1
# 324056        33046    37.0         1      1
# 324057        33046    19.0         1      1
#
#                                      subtitle ean (identificador producto)  \
# 0                  Coca-Cola Sabor Original                  7501055300075
# 1                  Coca-Cola Sabor Original                  7501055300075
# 2                Marolio Duraznos en Mitades                 7797470001998
# 3          Ala Lquido Lavarropas Baja Espuma                 7791290787230
# 4        Higienol Papel Higinico Simple Hoja                 7790250014904
# ...                                       ...                          ...
# 324053       Nucita Leche Chocolate y Nueces                 7702011012401
# 324054                 Boing Jugo de Manzana                   19836103052
# 324055                   Boing Jugo de Fresa                      75003166
# 324056  Chip's Papas Fritas Sabor Sal de Mar                 7501000266203
# 324057                    A Granel Salchicha                       GEN02MX
#
#                            brand  retail_amount       fecha weekday currency  \
# 0       Coca-Cola Sabor Original           14.0  2020-07-08     Wed      MXN
# 1       Coca-Cola Sabor Original           14.0  2020-07-08     Wed      MXN
# 2                        Marolio           94.0  2020-07-08     Wed      ARS
# 3                            Ala          205.0  2020-07-08     Wed      ARS
# 4                       Higienol           97.0  2020-07-08     Wed      ARS
# ...                          ...            ...         ...     ...      ...
# 324053                    Nucita          600.0  2020-12-13     Sun      COP
# 324054                     Boing           12.0  2020-12-13     Sun      MXN
# 324055                     Boing           12.0  2020-12-13     Sun      MXN
# 324056                    Chip's           37.0  2020-12-13     Sun      MXN
# 324057                  A Granel           19.0  2020-12-13     Sun      MXN
#
#         usd_retail_amount   revenue
# 0                0.614232  3.685390
# 1                0.614232  3.685390
# 2                1.326337  2.652673
# 3                2.892543  2.892543
# 4                1.368667  1.368667
# ...                   ...       ...
# 324053           0.175505  0.351011
# 324054           0.600279  0.600279
# 324055           0.600279  0.600279
# 324056           1.850861  1.850861
# 324057           0.950442  0.950442
#
# [324058 rows x 13 columns]
